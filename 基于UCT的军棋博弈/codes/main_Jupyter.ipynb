# %%
from 全局变量辅助 import *
from 基础函数 import *
from 变量 import *
import  logging
logging.basicConfig(level=logging.INFO)

# %%
def logit():
    概率表log()
    改变概率表(54,'工兵',0)
    概率表log()

# %%
#def main：
输入消息 = val('输入消息',input().split())
while 输入消息[0]!='END':
    if 输入消息[0] == 'INFO':
        信息处理INFO()
        print(val('输出消息'))
    elif 输入消息[0] == 'START':
        反馈布局START()
        print(val('输出消息'))
        #log######
        概率表log()
    elif 输入消息[0] == 'GO':
        信息处理GO指令()
        #行棋 ： 复刻当前棋局和概率表 ->>{ 抛针得到完备棋局 -> UTC算法得到最优解([起点,终点]) } -> 选择重复最多的最优解 
        行棋函数驱动()
        print(val('输出消息'))
        #log#####
        概率表log()
        val('棋盘').display()
    elif 输入消息[0] == 'RESULT':
        信息处理RESULT指令()
    elif 输入消息[0] == 'END':
        break
    elif 输入消息[0] == 'log':
        logit()
    else:
        break
    
    输入消息 = val('输入消息',input().split())
# Out:
# INFO 1.0
# DOEMsy
# START 1 1800 31
# ARRAY fgfgedegcdcikkibjahijljhh
# 棋子概率表:{
# 0:{司令:100,军长:100,师长:250,旅长:500,团长:500,营长:700,连长:2000,排长:2100,工兵:400,地雷:3250,炸弹:100,军旗:0,}
# 1:{司令:0,军长:0,师长:0,旅长:0,团长:0,营长:0,连长:0,排长:3000,工兵:0,地雷:2000,炸弹:0,军旗:5000,}
# 2:{司令:100,军长:100,师长:250,旅长:500,团长:500,营长:700,连长:2000,排长:2100,工兵:200,地雷:3250,炸弹:100,军旗:0,}
# 3:{司令:0,军长:0,师长:0,旅长:0,团长:0,营长:0,连长:0,排长:3000,工兵:0,地雷:2000,炸弹:0,军旗:5000,}
# 4:{司令:100,军长:100,师长:250,旅长:500,团长:500,营长:700,连长:2000,排长:2100,工兵:400,地雷:3250,炸弹:100,军旗:0,}
# 10:{司令:500,军长:500,师长:850,旅长:700,团长:600,营长:500,连长:600,排长:500,工兵:1000,地雷:3250,炸弹:1000,军旗:0,}
# 11:{司令:400,军长:400,师长:850,旅长:700,团长:600,营长:500,连长:800,排长:600,工兵:1000,地雷:3250,炸弹:900,军旗:0,}
# 12:{司令:400,军长:400,师长:850,旅长:700,团长:600,营长:500,连长:800,排长:600,工兵:1000,地雷:3250,炸弹:900,军旗:0,}
# 13:{司令:400,军长:400,师长:850,旅长:700,团长:600,营长:500,连长:800,排长:600,工兵:1000,地雷:3250,炸弹:900,军旗:0,}
# 14:{司令:500,军长:500,师长:850,旅长:700,团长:600,营长:500,连长:600,排长:500,工兵:1000,地雷:3250,炸弹:1000,军旗:0,}
# 20:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 22:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 24:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 30:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 31:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 33:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 34:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 40:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 42:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 44:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1500,连长:500,排长:500,工兵:2000,地雷:0,炸弹:1500,军旗:0,}
# 50:{司令:500,军长:500,师长:1000,旅长:1000,团长:1200,营长:2800,连长:1500,排长:1500,工兵:0,地雷:0,炸弹:0,军旗:0,}
# 51:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1000,连长:1500,排长:1500,工兵:2000,地雷:0,炸弹:0,军旗:0,}
# 52:{司令:500,军长:500,师长:1000,旅长:1000,团长:1100,营长:2800,连长:1600,排长:1500,工兵:0,地雷:0,炸弹:0,军旗:0,}
# 53:{司令:500,军长:500,师长:1000,旅长:1000,团长:1000,营长:1000,连长:1500,排长:1500,工兵:2000,地雷:0,炸弹:0,军旗:0,}
# 54:{司令:500,军长:500,师长:1000,旅长:1000,团长:1200,营长:2800,连长:1500,排长:1500,工兵:0,地雷:0,炸弹:0,军旗:0,}
# }
#
# 棋种概率表:{
# 司令:{0:100,1:0,2:100,3:0,4:100,10:500,11:400,12:400,13:400,14:500,20:500,22:500,24:500,30:500,31:500,33:500,34:500,40:500,42:500,44:500,50:500,51:500,52:500,53:500,54:500,}
# 军长:{0:100,1:0,2:100,3:0,4:100,10:500,11:400,12:400,13:400,14:500,20:500,22:500,24:500,30:500,31:500,33:500,34:500,40:500,42:500,44:500,50:500,51:500,52:500,53:500,54:500,}
# 师长:{0:250,1:0,2:250,3:0,4:250,10:850,11:850,12:850,13:850,14:850,20:1000,22:1000,24:1000,30:1000,31:1000,33:1000,34:1000,40:1000,42:1000,44:1000,50:1000,51:1000,52:1000,53:1000,54:1000,}
# 旅长:{0:500,1:0,2:500,3:0,4:500,10:700,11:700,12:700,13:700,14:700,20:1000,22:1000,24:1000,30:1000,31:1000,33:1000,34:1000,40:1000,42:1000,44:1000,50:1000,51:1000,52:1000,53:1000,54:1000,}
# 团长:{0:500,1:0,2:500,3:0,4:500,10:600,11:600,12:600,13:600,14:600,20:1000,22:1000,24:1000,30:1000,31:1000,33:1000,34:1000,40:1000,42:1000,44:1000,50:1200,51:1000,52:1100,53:1000,54:1200,}
# 营长:{0:700,1:0,2:700,3:0,4:700,10:500,11:500,12:500,13:500,14:500,20:1500,22:1500,24:1500,30:1500,31:1500,33:1500,34:1500,40:1500,42:1500,44:1500,50:2800,51:1000,52:2800,53:1000,54:2800,}
# 连长:{0:2000,1:0,2:2000,3:0,4:2000,10:600,11:800,12:800,13:800,14:600,20:500,22:500,24:500,30:500,31:500,33:500,34:500,40:500,42:500,44:500,50:1500,51:1500,52:1600,53:1500,54:1500,}
# 排长:{0:2100,1:3000,2:2100,3:3000,4:2100,10:500,11:600,12:600,13:600,14:500,20:500,22:500,24:500,30:500,31:500,33:500,34:500,40:500,42:500,44:500,50:1500,51:1500,52:1500,53:1500,54:1500,}
# 工兵:{0:400,1:0,2:200,3:0,4:400,10:1000,11:1000,12:1000,13:1000,14:1000,20:2000,22:2000,24:2000,30:2000,31:2000,33:2000,34:2000,40:2000,42:2000,44:2000,50:0,51:2000,52:0,53:2000,54:0,}
# 地雷:{0:3250,1:2000,2:3250,3:2000,4:3250,10:3250,11:3250,12:3250,13:3250,14:3250,20:0,22:0,24:0,30:0,31:0,33:0,34:0,40:0,42:0,44:0,50:0,51:0,52:0,53:0,54:0,}
# 炸弹:{0:100,1:0,2:100,3:0,4:100,10:1000,11:900,12:900,13:900,14:1000,20:1500,22:1500,24:1500,30:1500,31:1500,33:1500,34:1500,40:1500,42:1500,44:1500,50:0,51:0,52:0,53:0,54:0,}
# 军旗:{0:0,1:5000,2:0,3:5000,4:0,10:0,11:0,12:0,13:0,14:0,20:0,22:0,24:0,30:0,31:0,33:0,34:0,40:0,42:0,44:0,50:0,51:0,52:0,53:0,54:0,}
# }
#
# GO 0000 0 00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a787c9a9d71> in <module>
#      13         信息处理GO指令()
#      14         #行棋 ： 复刻当前棋局和概率表 ->>{ 抛针得到完备棋局 -> UTC算法得到最优解([起点,终点]) } -> 选择重复最多的最优解
# ---> 15         行棋函数驱动()
#      16         print(val('输出消息'))
#      17         #log#####
#
# E:\GitHs\JunQi\recode\codes\基础函数.py in 行棋函数驱动()
#     136         for line in 棋盘.棋局:
#     137             for chessID in line:
# --> 138                 if not 是己方棋子(chessID):
#     139                     敌人存活棋子[chessID] = 虚拟敌方棋子集合[chessID]
#     140
#
# NameError: name '是己方棋子' is not defined
